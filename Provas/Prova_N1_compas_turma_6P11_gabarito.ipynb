# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilhermePelegrina/Mackenzie/blob/main/Provas/Prova_N1_compas_turma_6P11_gabarito.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://raw.githubusercontent.com/guilhermepelegrina/Mackenzie/main/logo_mackenzie.png'>

# %% [markdown]
# # **Prova N1 - Análise de Dados - Turma 6P11**
#
# Este notebook contém as instruções e questões da Prova N1 para a disciplina de Análise de Dados da turma 6P11.

# %% [markdown]
# # Instruções
#
# ## Leitura dos dados
#
# Para responder as questões da prova, utilize o conjunto de dados [COMPAS Recidivism Risk](https://www.propublica.org/article/machine-bias-risk-assessments-in-criminal-sentencing), da ProPublica. A base de dados COMPAS contém diversos atributos descrevendo pessoas detidas por crimes. São eles:
#
# - `sex`: sexo.
#
# - `age_cat`: faixa etária.
#
# - `race`: raça.
#
# - `juv_fel_count`: número de crimes cometidos na juventude.
#
# - `juv_misd_count`: número de contravenções cometidos na juventude.
#
# - `juv_other_count`: número de condenações juvenis anteriores que não são consideradas crimes ou contravenções.
#
# - `priors_count`: número de crimes anteriores cometidos.
#
# - `c_charge_degree`: motivo de ter sido detido, se foi por crime (F) ou contravenção (M).
#
# Para cada pessoa, há também a indicação se esse indivíduo será um potencial reincidente criminal (ou seja, provavelemente vai cometer outro crime) ou não. Isso é indicado pelo atributo
#
# - `score_risk`: 1 indica que é classificado como possível reincidente e -1 indica que não.
#
# Para ler o conjunto de dados, utilize o arquivo `.csv` disponível no link abaixo:
#
# https://raw.githubusercontent.com/guilhermepelegrina/Mackenzie/main/Datasets/data_compas_projC1_train.csv
#
# ## Questões e respostas
#
# As questões se encontram logo ao final das instruções. Após cada questão, há células para inserirem códigos e buscarem pelas respostas (insira mais células, se necessário). Além disso, também há células de texto para que seja escrita a resposta da questão.
#
# ## Envio do notebook com as questões e respostas
#
# Após finalizar a prova, faça o download do notebook nos formatos `.ipynb` e `.pdf` (dois arquivos) e submeta no Moodle, da seguinte forma:
#
# - Antes de salvar o arquivo, confira se todas as questões, seus códigos e suas respostas estão no notebook.
#
# - Para fazer o download do notebook no formato `.ipynb`, clique em *Arquivo* - *Fazer download* - *Fazer o download do .ipynb*. Salve o arquivo com seu RA e nome (ex: 1172211_Guilherme).
#
# - Para fazer o download do notebook no formato `.pdf`, clique em *Arquivo* - *Imprimir*. Salve o arquivo com seu RA e nome (ex: 1172211_Guilherme). Confira se o arquivo contém todos os códigos e respostas.
#
# - Após fazer o download do notebook, submeta os arquivos no Moodle. Para isso, acesse o Moodle, vá até o tópico *Provas* - *Envio da Prova N1* e envie os arquivos. **Lembre-se de finalizar o envio!**

# %% [markdown]
# # BOA PROVA!

# %% [markdown]
# **Questão 1 (0,5 pontos)** Leia o arquivo mencionado acima. Há quantas colunas e quantas linhas nessa base de dados?

# %% [markdown]
# *Escreva aqui sua resposta:*
#
# 4000 e 9

# %%
# Escreva aqui seus códigos (insira mais células, se necessário)

import pandas as pd
dados = pd.read_csv('https://raw.githubusercontent.com/guilhermepelegrina/Mackenzie/main/Datasets/data_compas_projC1_train.csv')
dados
# Out:
#          sex          age_cat              race  juv_fel_count  \
# 0     Female  Greater than 45  African-American              0
# 1       Male     Less than 25  African-American              0
# 2       Male          25 - 45             Other              0
# 3       Male          25 - 45  African-American              0
# 4       Male     Less than 25  African-American              0
# ...      ...              ...               ...            ...
# 3995    Male  Greater than 45         Caucasian              0
# 3996  Female  Greater than 45         Caucasian              0
# 3997    Male  Greater than 45         Caucasian              0
# 3998    Male          25 - 45         Caucasian              0
# 3999    Male          25 - 45         Caucasian              0
#
#       juv_misd_count  juv_other_count  priors_count c_charge_degree  \
# 0                  0                0             0               F
# 1                  0                0             0               M
# 2                  0                0             1               F
# 3                  0                0             0               F
# 4                  0                0             2               F
# ...              ...              ...           ...             ...
# 3995               0                0            11               F
# 3996               0                0             2               M
# 3997               0                0             1               F
# 3998               0                0             5               F
# 3999               0                0             2               F
#
#       score_risk
# 0             -1
# 1              1
# 2             -1
# 3              1
# 4              1
# ...          ...
# 3995          -1
# 3996          -1
# 3997          -1
# 3998          -1
# 3999          -1
#
# [4000 rows x 9 columns]

# %% [markdown]
# **Questão 2 (0,5 pontos)** Há quantas raças descritas nessa base de dados? Indique quais são elas. Obs: considere *Other* como um tipo de raça.

# %% [markdown]
# *Escreva aqui sua resposta:*
#
# 3, 'African-American', 'Other', 'Caucasian'

# %%
# Escreva aqui seus códigos (insira mais células, se necessário)

dados['race'].unique()
# Out:
# array(['African-American', 'Other', 'Caucasian'], dtype=object)

# %% [markdown]
# **Questão 3 (0,5 pontos)** Qual a faixa etária do último indivíduo dessa base de dados?

# %% [markdown]
# *Escreva aqui sua resposta:*
#
# 25-45

# %%
# Escreva aqui seus códigos (insira mais células, se necessário)

dados.tail()
# Out:
#          sex          age_cat       race  juv_fel_count  juv_misd_count  \
# 3995    Male  Greater than 45  Caucasian              0               0
# 3996  Female  Greater than 45  Caucasian              0               0
# 3997    Male  Greater than 45  Caucasian              0               0
# 3998    Male          25 - 45  Caucasian              0               0
# 3999    Male          25 - 45  Caucasian              0               0
#
#       juv_other_count  priors_count c_charge_degree  score_risk
# 3995                0            11               F          -1
# 3996                0             2               M          -1
# 3997                0             1               F          -1
# 3998                0             5               F          -1
# 3999                0             2               F          -1

# %% [markdown]
# **Questão 4 (0,5 pontos)** Qual o segundo quartil do número de crimes anteriores cometidos? Lembre-se que, nesse caso, o primeiro quartil vai indicar o número mínimo de crimes anteriores cometidos por pelo menos 50% dos indivíduos.

# %% [markdown]
# *Escreva aqui sua resposta:*
#
# 1

# %%
# Escreva aqui seus códigos (insira mais células, se necessário)

dados['priors_count'].describe()
# Out:
# count    4000.000000
# mean        3.255250
# std         4.770669
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         4.000000
# max        38.000000
# Name: priors_count, dtype: float64

# %% [markdown]
# **Questão 5 (0,5 pontos)** Qual o percentual de indivíduos que possuem entre 25 e 45 anos nessa base de dados?

# %% [markdown]
# *Escreva aqui sua resposta:*
#
# 57,20 % (2288/4000)

# %%
# Escreva aqui seus códigos (insira mais células, se necessário)

dados['age_cat'].value_counts()
# Out:
# age_cat
# 25 - 45            2288
# Less than 25        871
# Greater than 45     841
# Name: count, dtype: int64

# %% [markdown]
# **Questão 6 (0,5 pontos)** Ao selecionarmos aleatoriamente 100 indivíduos dessa base de dados, quantos crimes, em média, eles teriam cometido na juventude?

# %% [markdown]
# *Escreva aqui sua resposta:*
#
# 5

# %%
# Escreva aqui seus códigos (insira mais células, se necessário)

dados['juv_fel_count'].mean()
# Out:
# 0.05275

# %% [markdown]
# **Questão 7 (1,0 ponto)** Para as mulheres (*Female*) com até 45 anos, quantas são tidas como potenciais reincidentes criminais?

# %% [markdown]
# *Escreva aqui sua resposta:*
#
# 283

# %%
# Escreva aqui seus códigos (insira mais células, se necessário)

len(dados[(dados.sex == 'Female') & (dados['age_cat'] != 'Greater than 45') & (dados['score_risk'] == 1)])
# Out:
# 283

# %% [markdown]
# **Questão 8 (1,0 ponto)** Dentre os homens (*Male*), qual porcentagem não são tidos como potenciais reincidentes criminais?

# %% [markdown]
# *Escreva aqui sua resposta:*
#
# 54,75%

# %%
# Escreva aqui seus códigos (insira mais células, se necessário)

len(dados[(dados.sex == 'Male') & (dados['score_risk'] == -1)])/len(dados[dados.sex == 'Male'])
# Out:
# 0.5475530932594644

# %% [markdown]
# **Questão 9 (1,0 ponto)** Ao comparar os homens e mulheres nessa base de dados e levando em conta apenas os indivíduos entre 25 e 45 anos, a pessoa que cometeu mais crimes anteriores é um homem ou uma mulher? Qual foi esse valor máximo encontrado?

# %% [markdown]
# *Escreva aqui sua resposta:*
#
# Homem, 31 crimes

# %%
# Escreva aqui seus códigos (insira mais células, se necessário)

dados.groupby(["sex","age_cat"])[["priors_count"]].max()
# Out:
#                         priors_count
# sex    age_cat
# Female 25 - 45                    23
#        Greater than 45            21
#        Less than 25                7
# Male   25 - 45                    31
#        Greater than 45            38
#        Less than 25               17

# %% [markdown]
# **Questão 10 (1,0 ponto)** Essa base de dados ficou conhecida por apresentar disparidades raciais. Verifique a porcentagem que os *Caucasian* e que os *African-American* são classificados como possíveis reincidentes criminais. A disparidade é grande? Considere que uma diferença maior que 10% indica uma disparidade grande. Justifique sua resposta com base nas porcentagens calculadas para cada raça.

# %% [markdown]
# *Escreva aqui sua resposta:*
#
# Caucasian: 32,14% (431/1341)
#
# African-American: 57,38% (1189/2072)
#
# Disparidade grande.

# %%
# Escreva aqui seus códigos (insira mais células, se necessário)

dados.groupby(["race","score_risk"]).count()
# Out:
#                               sex  age_cat  juv_fel_count  juv_misd_count  \
# race             score_risk
# African-American -1           883      883            883             883
#                   1          1189     1189           1189            1189
# Caucasian        -1           910      910            910             910
#                   1           431      431            431             431
# Other            -1           432      432            432             432
#                   1           155      155            155             155
#
#                              juv_other_count  priors_count  c_charge_degree
# race             score_risk
# African-American -1                      883           883              883
#                   1                     1189          1189             1189
# Caucasian        -1                      910           910              910
#                   1                      431           431              431
# Other            -1                      432           432              432
#                   1                      155           155              155

# %% [markdown]
# **Questão 11 (1,0 ponto)** Verifique, agora, se há disparidades em relação ao sexo. Verifique a porcentagem que as mulheres e os homens são classificados como não sendo possíveis reincidentes criminais. A disparidade é grande? Considere, também, que uma diferença maior que 10% indica uma disparidade grande. Justifique sua resposta com base nas porcentagens calculadas para cada sexo.

# %% [markdown]
# *Escreva aqui sua resposta:*
#
# Mulheres: 59,38% (446/751)
#
# Homens: 54,75% (1779/3249)
#
# Disparidade não é grande.

# %%
# Escreva aqui seus códigos (insira mais células, se necessário)

dados.groupby(["sex","score_risk"]).count()
# Out:
#                    age_cat  race  juv_fel_count  juv_misd_count  \
# sex    score_risk
# Female -1              446   446            446             446
#         1              305   305            305             305
# Male   -1             1779  1779           1779            1779
#         1             1470  1470           1470            1470
#
#                    juv_other_count  priors_count  c_charge_degree
# sex    score_risk
# Female -1                      446           446              446
#         1                      305           305              305
# Male   -1                     1779          1779             1779
#         1                     1470          1470             1470

# %% [markdown]
# **Questão 12 (1,0 ponto)** Crie uma nova coluna de dados (dê o nome que quiser) que indique, para cada indivíduo, a soma dos números de crimes e de contravenções que o mesmo cometeu na juventude. Calcule a média e a variância dessa nova coluna de dados.

# %% [markdown]
# *Escreva aqui sua resposta:*
#
# Média: 0.145
#
# Variância: 0.4035

# %%
# Escreva aqui seus códigos (insira mais células, se necessário)

dados['soma'] = dados['juv_fel_count'] + dados['juv_misd_count']
print(dados['soma'].mean(), dados['soma'].var())
# Out:
# 0.145 0.4035758939734935

# %% [markdown]
# **Questão 13 (1,0 ponto)** Com base nessa nova coluna criada na questão anterior, indique a raça, o sexo e a faixa etária da pessoa que cometeu o maior número de crimes ou contravenções na juventude.

# %% [markdown]
# *Escreva aqui sua resposta:*
#
# Homem caucasiano, menor de 25 anos.

# %%
# Escreva aqui seus códigos (insira mais células, se necessário)

dados.groupby(['race','sex','age_cat']).max()
# Out:
#                                          juv_fel_count  juv_misd_count  \
# race             sex    age_cat
# African-American Female 25 - 45                      3               3
#                         Greater than 45              0               1
#                         Less than 25                 1               3
#                  Male   25 - 45                      6               8
#                         Greater than 45              4               0
#                         Less than 25                 5               5
# Caucasian        Female 25 - 45                      0               1
#                         Greater than 45              0               1
#                         Less than 25                 0               3
#                  Male   25 - 45                      6               6
#                         Greater than 45              1               0
#                         Less than 25                 8               2
# Other            Female 25 - 45                      0               1
#                         Greater than 45              0               0
#                         Less than 25                 1               1
#                  Male   25 - 45                      2               4
#                         Greater than 45              4               0
#                         Less than 25                 2               8
#
#                                          juv_other_count  priors_count  \
# race             sex    age_cat
# African-American Female 25 - 45                        2            23
#                         Greater than 45                1            21
#                         Less than 25                   3             7
#                  Male   25 - 45                        5            29
#                         Greater than 45                2            38
#                         Less than 25                   6            17
# Caucasian        Female 25 - 45                        2            20
#                         Greater than 45                0            15
#                         Less than 25                   4             3
#                  Male   25 - 45                        3            22
#                         Greater than 45                1            36
#                         Less than 25                   5            11
# Other            Female 25 - 45                        2            10
#                         Greater than 45                0            15
#                         Less than 25                   1             2
#                  Male   25 - 45                        1            31
#                         Greater than 45                0            23
#                         Less than 25                   3             8
#
#                                         c_charge_degree  score_risk  soma
# race             sex    age_cat
# African-American Female 25 - 45                       M           1     3
#                         Greater than 45               M           1     1
#                         Less than 25                  M           1     3
#                  Male   25 - 45                       M           1     9
#                         Greater than 45               M           1     4
#                         Less than 25                  M           1     6
# Caucasian        Female 25 - 45                       M           1     1
#                         Greater than 45               M           1     1
#                         Less than 25                  M           1     3
#                  Male   25 - 45                       M           1     7
#                         Greater than 45               M           1     1
#                         Less than 25                  M           1    10
# Other            Female 25 - 45                       M           1     1
#                         Greater than 45               M           1     0
#                         Less than 25                  M           1     1
#                  Male   25 - 45                       M           1     5
#                         Greater than 45               M           1     4
#                         Less than 25                  M           1     8
